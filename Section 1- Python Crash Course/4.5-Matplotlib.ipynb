# %% [markdown]
# ## MatplotLib Tutorial
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
plt.scatter(x,y,c='g')

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='r')
plt.xlabel('age')
plt.ylabel('height')
plt.title('Graph in 2D')
plt.savefig('Test123.png')

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'r*',linestyle='dashed')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
x= np.arange(0,10)
y= np.random.randint(1,10,10)
plt.plot(x,y)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
# print(x)
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
x1 = [2, 8, 10]
y1 = [11, 16, 9]

x2 = [3, 9, 11]
y2 = [6, 15, 7]

plt.figure(figsize=(10, 6))  # Adjust figure size if needed

plt.subplot(1, 2, 1)  # Create subplot 1 (left side)
plt.bar(x1, y1, color='b')
plt.title('Bar Graph 1')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.subplot(1, 2, 2)  # Create subplot 2 (right side)
plt.bar(x2, y2, color='g')
plt.title('Bar Graph 2')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.tight_layout()  # Adjust subplot layout for better spacing
plt.show()

# %% [markdown]
# ## Histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# print(data)
# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);  
plt.boxplot(data, tick_labels=["std=1", "std=2", "std=3"])
plt.title("Boxplot of Normally Distributed Data")
plt.ylabel("Values")
plt.show()

# %%
data
# Out:
# [array([ 0.94444073, -0.30873739,  0.62578637, -0.63602655, -0.26544366,
#          0.03159838,  0.54154963,  3.59498582, -0.79652196,  0.55487353,
#         -0.23608146, -0.50280317, -0.95510061,  0.91659936, -0.02552402,
#          0.19879798, -0.31971501, -1.11195869,  1.15393544,  1.35050557,
#         -0.07711951,  0.7127786 ,  0.58717979,  0.90678321,  1.70241226,
#          0.36308425,  0.24573107, -1.301996  , -1.54460452,  1.19998788,
#         -1.19770539, -0.51694194,  1.12603988,  0.11292427, -0.19261645,
#          0.6065257 ,  1.00731765,  0.48297345, -0.27778254, -1.14705099,
#          0.62160182,  1.16463101, -0.74671513, -0.12380849, -1.02105838,
#         -0.38583601,  2.22918345, -0.04791293, -0.2118474 ,  0.00924834,
#          0.05072808,  2.28336475,  1.17107581,  0.55933744, -1.58373137,
#          0.90063867,  0.25430671,  0.40583876,  0.72034283,  0.32417528,
#          0.60954102, -0.36081602,  0.73656963,  1.16365541,  0.22237786,
#         -1.35874784, -0.23808493,  0.64877279, -1.49709911, -0.25445797,
#         -0.88152333, -2.32872119,  1.58369738,  1.28020645,  1.75633188,
#          0.45323635, -0.11211792, -0.1126764 ,  1.22768451,  0.81701459,
#         -0.22122377, -1.13166648,  0.25010553, -1.50359752, -0.6672838 ,
#         -0.35939078, -0.64505894, -2.12775287,  1.93877478, -0.10382853,
#          0.36213004, -1.17084307,  0.13626755, -0.21256371, -1.13188198,
#         -0.12281245,  1.76615816, -1.34419749, -1.60126003, -0.13517021]),
#  array([ 1.91381075, -0.25301588, -0.49048672,  0.16609194,  2.40680034,
#          0.41798092, -1.65112208,  1.44265222,  1.09213797,  1.41601675,
#         -1.85016431, -0.43976648, -0.54018763, -0.29490786,  0.60743233,
#          1.3193737 , -1.1256003 ,  0.54166829,  6.59716365, -0.37725909,
